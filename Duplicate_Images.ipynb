# %%
import hashlib
from scipy.misc import imread
import matplotlib.pyplot as plt
# %matplotlib inline
import time
import numpy as np

# %%
from hashlib import md5

# %%
def file_hash(filepath):
  with open(filepath,'rb') as f:
    return md5(f.read()).hexdigest()

# %%
import os

# %%
os.chdir(r'H:\Work\Car Brand Prediction CNN\Datasets\Train\ferrari')

# %%
os.getcwd()
# Out:
# 'H:\\Work\\Car Brand Prediction CNN\\Datasets\\Train\\ferrari'

# %%
files_list = os.listdir()

# %%
print(len(files_list))
# Out:
# 369

# %%
duplicates = []
hash_keys = dict()
for index, filename in  enumerate(os.listdir('.')):  #listdir('.') = current directory
    if os.path.isfile(filename):
        with open(filename, 'rb') as f:
            filehash = hashlib.md5(f.read()).hexdigest()
        if filehash not in hash_keys: 
            hash_keys[filehash] = index
        else:
            duplicates.append((index,hash_keys[filehash]))

# %%
duplicates
# Out:
# [(131, 128), (161, 104)]

# %%
for file_indexes in duplicates[:30]:
    try:
    
        plt.subplot(121),plt.imshow(imread(files_list[file_indexes[1]]))
        plt.title(file_indexes[1]), plt.xticks([]), plt.yticks([])

        plt.subplot(122),plt.imshow(imread(files_list[file_indexes[0]]))
        plt.title(str(file_indexes[0]) + ' duplicate'), plt.xticks([]), plt.yticks([])
        plt.show()
    
    except OSError as e:
        continue
# Out:
# H:\Softwares\Anaconda\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   after removing the cwd from sys.path.
# H:\Softwares\Anaconda\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   import sys

# %%
for index in duplicates:
    os.remove(files_list[index[0]])
